# %% [markdown]
# # Examples

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.randint(low=0, high=10, size=(5, 5)), columns=['a', 'b', 'c', 'd', 'e'])

# %%
import eda_utils as eda

# %%
eda.correlation_plot(df)
# Out:
#           a         b         c         d         e
# a  1.000000 -0.592852  0.264174  0.039043 -0.336910
# b -0.592852  1.000000  0.382851  0.737261  0.652187
# c  0.264174  0.382851  1.000000  0.422885 -0.154022
# d  0.039043  0.737261  0.422885  1.000000  0.686406
# e -0.336910  0.652187 -0.154022  0.686406  1.000000

# %%
eda.correlation_plot(df, method = 'mic-r2')
# Out:
#           a         b         c         d         e
# a -0.029049 -0.270924  0.155799  0.282885 -0.014982
# b -0.270924 -0.029049  0.588100  0.233690  0.318763
# c  0.155799  0.588100 -0.029049 -0.002912  0.265952
# d  0.282885  0.233690 -0.002912 -0.029049  0.284544
# e -0.014982  0.318763  0.265952  0.284544 -0.029049

# %%
eda.correlation_plot(df, method = 'mic')
# Out:
#           a         b         c         d         e
# a  0.970951  0.321928  0.419973  0.321928  0.321928
# b  0.321928  0.970951  0.970951  0.970951  0.970951
# c  0.419973  0.970951  0.970951  0.419973  0.419973
# d  0.321928  0.970951  0.419973  0.970951  0.970951
# e  0.321928  0.970951  0.419973  0.970951  0.970951
